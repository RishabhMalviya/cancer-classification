# %% [markdown]
# # Display Images

# %%
from PIL import Image

from IPython.display import display

# %% [markdown]
# ## Lymphocyte Image

# %%
im  = Image.open('../1_raw/NCT-CRC-HE-100K/LYM/LYM-AAALPRRV.tif')
display(im)
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=224x224>

# %% [markdown]
# ## Adipose

# %%
im = Image.open('../1_raw/NCT-CRC-HE-100K/ADI/ADI-AACVGRFT.tif')
display(im)
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=224x224>

# %% [markdown]
# ## Background

# %%
im = Image.open('../1_raw/NCT-CRC-HE-100K/BACK/BACK-AAAGSRKS.tif')
display(im)
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=224x224>

# %% [markdown]
# ## Debris

# %%
im = Image.open('../1_raw/NCT-CRC-HE-100K/DEB/DEB-AACPLMQN.tif')
display(im)
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=224x224>

# %% [markdown]
# # Create DataLoader

# %%
import os
import torch
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split, Subset

# %%
# Load dataset using ImageFolder
dataset = datasets.ImageFolder("../1_raw/NCT-CRC-HE-100K/")
type(dataset)
# Out:
# torchvision.datasets.folder.ImageFolder

# %% [markdown]
# ## Tran/Val/Test Split

# %%
train_size = int(0.8 * len(dataset))
val_size = int(0.1 * len(dataset))
test_size = len(dataset) - train_size - val_size

# %%
train_indices, val_indices, test_indices = random_split(range(len(dataset)), [train_size, val_size, test_size])

# %%
train_set = Subset(dataset, train_indices)
val_set = Subset(dataset, val_indices)
test_set = Subset(dataset, test_indices)

# %%
# DataLoaders
train_loader = DataLoader(train_set, batch_size=64, shuffle=True, num_workers=4)
val_loader = DataLoader(val_set, batch_size=64, shuffle=False, num_workers=4)
test_loader = DataLoader(test_set, batch_size=64, shuffle=False, num_workers=4)
